# %%
import pandas as pd

# %%
pd.read_excel('http://qrc.depaul.edu/Excel_Files/Presidents.xls')
# Out:
#                  President Years in office  Year first inaugurated  \
# 0        George Washington               8                    1789
# 1               John Adams               4                    1797
# 2         Thomas Jefferson               8                    1801
# 3            James Madison               8                    1809
# 4             James Monroe               8                    1817
# 5        John Quincy Adams               4                    1825
# 6           Andrew Jackson               8                    1829
# 7        Martin Van Buren                4                    1837
# 8   William Henry Harrison             0.8                    1841
# 9            James K. Polk               4                    1845
# 10          Zachary Taylor               1                    1849
# 11         Franklin Pierce               4                    1853
# 12          James Buchanan               4                    1857
# ...

# %%
df = pd.read_csv('https://github.com/minsuk-heo/pandas/blob/master/data/friend_list.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-3078c41ad217> in <module>()
# ----> 1 df = pd.read_csv('https://github.com/minsuk-heo/pandas/blob/master/data/friend_list.csv')
#
# ...

# %%
df = pd.read_csv('friend_list.csv')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df.head(2)
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer

# %%
df.tail(3)
# Out:
#     name  age      job
# 3  Julia   40  dentist
# 4  Brian   45  manager
# 5  Chris   25   intern

# %%
df = pd.read_csv('friend_list_tab.txt')

# %%
df
# Out:
#          name\tage\tjob
# 0     John\t20\tstudent
# 1  Jenny\t30\tdeveloper
# 2     Nate\t30\tteacher
# 3    Julia\t40\tdentist
# 4    Brian\t45\tmanager
# 5     Chris\t25\tintern

# %%
df = pd.read_csv('friend_list_tab.txt',delimiter='\t')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern
